# %%
import tweepy
import csv
import pandas as pd

# %%
class Twitter_Data_Downloader:
    
    def __init__(self):
        consumer_key = '1aWY7LUDcpfRinxw31OFOcbzI'
        consumer_secret = 'NJ0DllMlhoSrWazB2BtAVO21K5rhKKnZzAGL00WmZ1M1YSNHq8'
        access_token = '2904265662-Zv1kX1y1k1Nky8dpMmKJJzrAQLYdQVdDLNwgiYs'
        access_token_secret = '7dofFG4oUInt6L7vPClauLz7jJMVZvxbuo9ta9Ec4HJuC'
        auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
        auth.set_access_token(access_token, access_token_secret)
        self.api = tweepy.API(auth, wait_on_rate_limit=True)        
        
        
    def get_data(self, hashtag, since):
        row = {}
        data = pd.DataFrame(columns= ['user_id','created_at','tweet','hashtags',
                                    'retweet_count','favourite_count', 'tweet_url','user_location'])
        
        
        count = 0

        for tweet in tweepy.Cursor(self.api.search, q=hashtag, lang="en", since=since).items(10):
            #print ("\n", tweet.created_at, tweet.text.encode('utf8'))
            row.update({'user_id' : tweet.author.screen_name.encode('utf8')})
            row.update({'created_at' : tweet.created_at})    
            row.update({'tweet' : tweet.text.encode('utf8')})
            row.update({'hashtags' : tweet.entities.get('hashtags')})
            row.update({'retweet_count' : tweet.retweet_count})
            row.update({'favourite_count' : tweet.favorite_count})
            row.update({'tweet_url' : tweet.entities.get('url')})
            row.update({'tweet_urls' : tweet.entities['urls']})
            row.update({'user_location' : tweet.author.location})

            
            data = data.append(row, ignore_index= True)
            
            count += 1
            if(count % 100 == 0):
                print('Download count: ',count)

        name = hashtag.split("#")[1]
        name = "dataset/raw_dataset/"+name+"_new.csv"
        data.to_csv(name)
        
        return data
            
    def read_data(self, hashtag):
        name = hashtag.split("#")[1]
        name = "dataset/raw_dataset/"+name+".csv"
        df = pd.read_csv(name)
        return df

# %%
tdd = Twitter_Data_Downloader()

# %%
hashtag = "#Referendum2020"
df = pd.DataFrame()
df = tdd.get_data(hashtag, "2019-01-01")
# Out:
# Bogotá, D.C., Colombia
# Jamshedpur, India
# Bogotá, D.C., Colombia
#
#
#
#
#
# EARTH
#
# Dunedin South MP
# Punjab, India
# Chandigarh, India
#
#
#
# भारत
#
#
# BIAFRANS
#
#
# Mumbai, India
# India
#
# India
# New Delhi, India
# Paris
#
# Pinellas County, FL
#
# India
#
#
# St. Petersburg, Florida
# St Petersburg, FL
# भारतवर्ष
# Ft. Lauderdale, FL
# Pinellas County, FL
#
# New Delhi
#
# St. Petersburg, FL
#
#
# Hindustan
# Mumbai
#
#
# Pakistan
#
# Wellington City, New Zealand
# Auckland, New Zealand
# India
# India
# New Zealand
#
# Maharashtra, India
# India
# India
# India
# India
#
#
#
#
#
#
#
#
#
# रामगुडीपारा,रायगढ़,छ.गढ़,भारत
# Wellington
# Uttaranchal, India
# New Delhi
#
#
# Kolkata, India
# Mumbai, India
# New Zealand
#
#
# Texas, USA
#
# New Zealand
#
# Wellington
#
# New Delhi, India
# Uttar Pradesh, India
# India
# Bangalore
#
# London, England
#
# New Zealand
#
#
# Mumbai, India
#
# Download count:  100
#
# United Kingdom
# Auckland, New Zealand
#
# California, USA
# Ludhiana, India
# Old Faridabad, Faridabad
#
#
#
# Biafraland
#
# Outside The Box
#
#
# Uk
# Agra, India
# Lagos, Nigeria
#
#
# Punjab, India
# Mexico
# Silicon Valley #innovation
# Auckland, New Zealand
# Sydney, New South Wales
# India भारत-भूमि
# India
# India
# Indus River, INDIA, Nepal
# Central Finland, Finland
#
#
#
#
# Old Faridabad, Faridabad
# PkMKB
#
#
#
# Delhi, India
#
# Jalandhar, India
# BIAFRA NATION♀️🇱🇷🇮🇱
# Senegal
# Lahore, Pakistan
# Earth
# Earth
# Earth
# New Zealand
# INDIA
# Jharkhand, India
#
# Aotearoa New Zealand
#
#
#
#
# Rajkot, India
#
#
#
# MA USA
# Bangalore,Bharat
#
#
#
# Surat, India
#
#
# Dublin City, Ireland
#
# India
#
# बेंगलुरु-कर्नाटक-भारतवर्ष
# India
# india
# भारतवर्ष🚩
# Boat
# faridabad
# Everywhere
#
#
# India
#
#
# 🚩 Hindutva Matters 🚩
# J&K/Bangalore/UK
# India
#
#
# Port Harcourt, Nigeria
# Port Harcourt, Nigeria
#
# Bharat
# India
# India
# भारत-मुंबई-पंजाब-ENGLAND
# 🇬🇧
# UK
# 9 realms
# Download count:  200
#
#
# Sohana, Mohali
#
#
# भारत
# Sohana, Mohali
#
#
#
#
#
# India
# Jammu And Kashmir UT
# Jaipur, India
# Laxminagar, Delhi
# New Delhi, India
#
#
# भारत
# CHINA
#
# Wellington, Aotearoa
# London, England
# Bihar,Nepal
# London, England
#
# Wellington
# Guwahati,Punjab,J&K,Shillong.
# 🚩 Hindutva Matters 🚩
# where I belong from.
# New Delhi, India
# New Delhi, India
#
# जम्मू औरकश्मीर,UT, जम्बुद्वीप
# Baheri, India
# Chandigarh, India
# Nigeria
# Uttaranchal, India
#
#  ✈️ Silicon Valley
# USA
# Mumbai, India
# Travel India/Can/Aus/Amr
#
#
# Kolkata, India
#
# Prague, Czech Republic
# जलंधर, भारत
# Bern
#
# Hyderabad, India
# India
#
#
#
#
#
#
# USA
# India
#
#
# Okanagan, Alberta
# Prishtinë
#
#
# Switzerland
# Delhi
#
# New Zealand
# Srinagar, India
# Kolkata, India
#
#
# Berhampur
# India
# India
# भारत
# Awka, Nigeria
#
#
#
# Lucknow ,Uttar Pradesh
#
#
# Jamshedpur, India
#
# India
#
#
# New Delhi, India
# Mohali Sector 60 Phase 3B Part
#
#
# London, England
#
# History's Origin Point - India
# New Delhi
# Download count:  300
#
#
# United Kingdom
#
#
# Bengaluru, India
#
# California, USA
#
# Uttar Pradesh, India
# Nairobi, Kenya
#
#
#
# Punjab India
# India
#
# भारत
#
# New Zealand
#
# India
# land of cholas
#
# India
# London, England
#
#
#
#
#
#
# आर्यवर्त
#
#
#
# New Delhi, India
# New Delhi, India
# Sri Lanka
# Rai Singh nagar
# India
# Rai Singh nagar
#
# India
#
#
# Sydney, New South Wales
# भारत
# India
# Ihechiowa Biafra
# Bharat
#
# Leicester, England
# Ghaziabad, India
# Vikhroli East, Mumbai
# Geneva Switzerland
#
#
#
#
#
#
#
#
# India
# भारत
#
#
# India
#
#
# Chandigarh, India
#
# Kolkata, India
#
# India
# Akwa ibom state Nigeria
#
# Lahore, Pakistan
#
#
# U.A.E
# Najran,Kingdom of Saudi Arabia
# California, USA
# Earth.
# Birmingham, England
# Antarctica-76°10'12.4"S 20°03
# Ludhiana, India
#
#
# Makkah Al Mukarrama, Kingdom o
# پاکستان
#
#
# Sindh, Pakistan
#
#
#
#
# MA USA
# Download count:  400
#
#
#
# Washington, DC
#
# India
#
#
#
# بدین بریگیڈ ہیڈکوارٹرز, پاکستا
#
#
# jahan tum
# Islamabad Pakistan
#
#
# India
# Muscat, Oman
#
# Central Finland, Finland
#
# City Of Saints 🕌
# Islamabad
# Karachi, Pakistan
# Mirpur Mathelo, Hyderabad
# 🚩੧ਓ🇮🇳  @narendramodi
#
#
# Manchester
#
# New Delhi
#
# Kolkata, India
#
#
#
#
# Wellington
# On Your HEAD.
#
# milkyway
#
#
# Gilgit-Baltistan, Pakistan
# Pakistan
# La La Land
#
# Afghanistan
#
#
#
# نہیں بتاوں گی 🙈
#
# Bihar,Nepal
#
#
# Pakistan
#
# Multan
# Pakistan
# Pakistan
# Lahore, Pakistan
#
#
# Rabigh, Kingdom of Saudi Arabi
# daska
# PAKISTAN
#
# Indian Punjab
# Peshawar, Pakistan
# گجرات, پاکستان
# Pakistan
#
#
#
# Australia
#
# Kolkata, India
# London
#
#
#
#
# Uttaranchal, India

# %%
data = tdd.read_data(hashtag)
data
# Out:
#       Unnamed: 0            user_id           created_at  \
# 0              0   b'OJIOGUOJIOGU2'  2020-09-29 11:50:25
# 1              1    b'tonytonerro9'  2020-09-29 11:49:29
# 2              2   b'Jamshaid_2012'  2020-09-29 07:19:54
# 3              3        b'jmez1010'  2020-09-29 06:53:52
# 4              4        b'jmez1010'  2020-09-29 06:39:49
# ...          ...                ...                  ...
# 1099        1099   b'GiuliaOlivaUK'  2020-09-20 15:19:49
# 1100        1100        b'KappaGee'  2020-09-20 14:31:54
# 1101        1101    b'deathcold666'  2020-09-20 14:12:21
# 1102        1102    b'deathcold666'  2020-09-20 14:11:38
# 1103        1103  b'Singh_Gurmeeet'  2020-09-20 14:10:49
#
#                                                   tweet  \
# 0     b'RT @EzeobiZ: @EmekaGift @antonioguterres @re...
# 1     b'RT @EzeobiZ: @EmekaGift @antonioguterres @re...
# 2     b'RT @Suleman2552: The Sikh community all over...
# 3     b"RT @Jasleen_Kaur11: \xf0\x9f\xa4\xa3\xf0\x9f...
# 4     b"RT @Jasleen_Kaur11: Pannun, a Pakistani pupp...
# ...                                                 ...
# 1099                           b'#Referendum2020 voted'
# 1100  b'Did my part for democracy, you should too. I...
# 1101  b'RT @Singh_Gurmeeet: True face of #Khalistan....
# 1102  b'RT @Singh_Gurmeeet: Sikhs r suffering in #Pa...
# 1103  b'Sikhs r suffering in #Pakistan &amp; #ISI is...
#
#                                                hashtags  retweet_count  \
# 0               [{'text': 'IPOB', 'indices': [93, 98]}]              3
# 1               [{'text': 'IPOB', 'indices': [93, 98]}]              3
# 2                                                    []             52
# 3     [{'text': 'Kashmir_With_India', 'indices': [85...              5
# 4                                                    []             29
# ...                                                 ...            ...
# 1099   [{'text': 'Referendum2020', 'indices': [0, 15]}]              0
# 1100  [{'text': 'Referendum2020', 'indices': [62, 77]}]              0
# 1101  [{'text': 'Khalistan', 'indices': [33, 43]}, {...              1
# 1102  [{'text': 'Pakistan', 'indices': [41, 50]}, {'...              1
# 1103  [{'text': 'Pakistan', 'indices': [21, 30]}, {'...              1
#
#       favourite_count                                          tweet_url
# 0                   0                                                 []
# 1                   0                                                 []
# 2                   0                                                 []
# 3                   0                                                 []
# 4                   0                                                 []
# ...               ...                                                ...
# 1099                0                                                 []
# 1100                3                                                 []
# 1101                0                                                 []
# 1102                0                                                 []
# 1103                1  [{'url': 'https://t.co/5S825hxm9y', 'expanded_...
#
# [1104 rows x 8 columns]

# %%
data['user_location']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'user_location'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-e739c40682e3> in <module>
# ----> 1 data['user_location']
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'user_location'
