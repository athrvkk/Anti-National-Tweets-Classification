# %%
import numpy as np
import pandas as pd
import re
from string import punctuation
from time import process_time
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import unicodedata
import preprocessor as p

# %%
class Preprocess_Data():
    
    # ----------------------------------------- Constructor -----------------------------------------
    
    def __init__(self):
        self.punctuation = set(punctuation)
        self.lemmatizer = WordNetLemmatizer()
        p.set_options(p.OPT.URL, p.OPT.EMOJI, p.OPT.MENTION, p.OPT.RESERVED, p.OPT.SMILEY)
        self.stopword_list = set(stopwords.words('english'))
        unwanted_stopwords = {'no', 'nor', 'not', 'ain', 'aren', "aren't", 'couldn', 'what', 'which', 'who',
                              'whom', 'why', 'how', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn',
                              "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn',
                              "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn',
                              "shouldn't", 'wasn',"wasn't",'weren', "weren't", 'won', "won't", 'wouldn',
                              "wouldn't", 'don', "don't"}

        self.stopword_list = [x for x in self.stopword_list if x not in unwanted_stopwords]
       
    
    # ----------------------------------------- Read Data -----------------------------------------
    
    def read_data(self, path):
        df = pd.read_csv(path, usecols=['user_id', 'tweet'])
        return df
    
    
    # ----------------------------------------- Clean Data -----------------------------------------
    
    def clean_data(self, tweets):
        cleaned_tweets = []
        for text in tweets:
            
            # Clean tweet
            text = p.clean(text)
            
            # Remove special characters
            text = re.sub(r'(\\x(.)*)', '',text)
            text = re.sub(r'\\n|\\t|\\n\\n', ' ', text)
            text = re.sub(r"b'RT|b'|b RT|b\"RT|b", "", text)
            text = re.sub("[@#$%^&*)(}{|/><=+=_:\"\\\\]+"," ",text).strip()
            
            #Remove punctuation marks
            text = "".join(x for x in text if x not in self.punctuation)
            
            # Remove accented words
            text = unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8', 'ignore')
            
            # Splitting Hashtag words
            text = " ".join([x for x in re.split('([A-Z][a-z]+)', text) if x])
            
            # Remove long spaces
            pattern = r'^\s*|\s\s*'
            text = re.sub(pattern, ' ', text).strip()
            
            # Remove numbers
            text = re.sub('[0-9]+', '', text)
            
            cleaned_tweets.append(text)
        
        return cleaned_tweets
    
    
    # ----------------------------------------- Preprocess Data -----------------------------------------
    
    def preprocess_data(self, tweets):
        preprocessed_tweets = []
        for text in tweets:
            
            # Remove stopwords
            text = " ".join(x for x in text.lower().split() if x not in self.stopword_list)
            
            # Text Lemmatization
            lemmatized_words = []
            for word in text.split():
                word1 = self.lemmatizer.lemmatize(word, pos="n")
                word2 = self.lemmatizer.lemmatize(word1, pos="v")
                word3 = self.lemmatizer.lemmatize(word2, pos=("a"))
                lemmatized_words.append(word3)
            text = " ".join(x for x in lemmatized_words)
            
            preprocessed_tweets.append(text)
            
        return preprocessed_tweets

# %%
pre = Preprocess_Data()

# %%
input_path = "dataset/raw_dataset/khalistan_main.csv"
output_path = "dataset/cleaned_dataset/khalistan_cleaned.csv"

path1 = "../Anti-National-Tweets-Classification/dataset/raw_dataset/control_tweets.csv"
path2 = "../Anti-National-Tweets-Classification/dataset/raw_dataset/khalistan_main.csv"
path3 = "../Anti-National-Tweets-Classification/dataset/raw_dataset/Referendum2020.csv"

# data1 = pre.read_data(input_path)
# data
d1 = pd.read_csv(path1)
d2 = pre.read_data(path2)
d3 = pre.read_data(path3)

# %%
# raw_tweets = data.tweet.values.tolist()
# raw_tweets[:2]
r1 = d1.tweet_low.values.tolist()
r2 = d2.tweet.values.tolist()
r3 = d3.tweet.values.tolist()

# %%
# cleaned_tweets = pre.clean_data(raw_tweets)
# cleaned_tweets

c1 = pre.clean_data(r1)
c2 = pre.clean_data(r2)
c3 = pre.clean_data(r3)

# %%
#Save cleaned

# %%
# preprocess_tweets = pre.preprocess_data(cleaned_tweets)
# preprocess_tweets

p1 = pre.preprocess_data(c1)
p2 = pre.preprocess_data(c2)
p3 = pre.preprocess_data(c3)

# %%
p2
# Out:
# ['pil file twitter promote khalistan good initiative sikh community try sa',
#  '',
#  'pakistan around partition weve never see photograph colour ehsan rehan first photograph gurdwara',
#  'pannun no shame leave',
#  'pannun pakistani puppet who work pakistan see indian sikh answer referendum shame',
#  'pil file twitter promote khalistan good initiative sikh community try sa',
#  '',
#  'pakistan around partition weve never see photograph colour ehsan rehan first photograph gurdwara',
#  'pannun no shame leave',
#  'pannun pakistani puppet who work pakistan see indian sikh answer referendum shame',
#  'no khalistan khai garbage dear sikh quick realise pannun',
#  'pannun not listen real sikh imaginary world doesnt care sikh community',
#  '',
#  'sikh justice mislead sikh community name khalistan support pakistan',
#  'gherao sept truck rally day modi solution farmersbill sfj khalistan register',
#  'sikh justice mislead sikh community name khalistan support pakistan',
#  'pig india no no not regular pig who demand loha sharia pig who demand',
#  'gherao sept truck rally day modi solution farmersbill sfj khalistan',
#  'pannun not listen real sikh imaginary world doesnt care sikh community',
#  'mp barrs journalist view tweet mean mp scar hold accountable',
#  'what would call video watch tight slap dose humiliation sfj khalistani separ',
#  'fight khalistan result mainly two thing carnage innocent people resurgence hatred soci',
#  'b namaste invite watch late video terry milewski report expose pakistan role khalistan move',
#  'sikh justice mislead sikh community name khalistan support pakistan',
#  'farmer register vote october maximum register vote get grant money sfj',
#  'like fail agenda pannun door door campaign go super failure nahi chahida k',
#  'no way leave modi except may free kashmir vacant space way',
#  'no way leave modi except may free kashmir vacant space way',
#  'pakistan around partition weve never see photograph colour ehsan rehan first photograph gurdwara',
#  'fight khalistan result mainly two thing carnage innocent people resurgence hatred soci',
#  'mr pannun what real indian sikh want sikh inseparable part india proud',
#  'mr pannun what real indian sikh want sikh inseparable part india proud',
#  'canadian thinktank recently publish report which argue khalistan separatist movement project',
#  'exclusive break news khalistani supporter video show khalistan not subject',
#  'solution farmersbill khalistan sfj modi register vote',
#  'cm gherao modi truck rally th sept solution farmersbill sfj khalistan',
#  'mr pannun what real indian sikh want sikh inseparable part india proud',
#  'please stop rally cm gherao modi truck rally th sept solution',
#  'punjab deep sht cm talk amp behave like goongetting chakka jam rail roko do',
#  'solution farmersbill sfj khalistan th september get ready',
#  'cm gherao modi truck rally th sept solution farmersbill sfj',
#  'oops what happen video go break every khalistanis dream socalled khalistan',
#  'cm solution farmersbill sfj khalistan register vote khalistan',
#  'punjab farmer sikh punjab show power modi protest policy ge',
#  'get ready gherao modi truck rally th sept solution farmersbill suffer farmer',
#  'sfj gunda gang launch another application google play store which motive spread hate among sikh',
#  'sikh justice mislead sikh community name khalistan support pakistan',
#  'get ready gherao modi truck rally th sept solution farmersbill suffer farmer',
#  'get ready gherao modi truck rally th sept solution farmersbill suffer farmer',
#  'cm gherao modi truck rally th sept solution farmersbill sfj khalistan farmer w',
#  'b account withhold india response legal demand learn',
#  'start trend pakistan remember dr najeeb khalistan notifydecisionsofcommission payandserviceprotecti',
#  'b account withhold india response legal demand learn',
#  'pannun no shame leave',
#  'cm gherao modi truck rally th sept solution farmersbill sfj khalistan',
#  'shame khalistani supporter whoever do no right stay punjab request leave ou',
#  'pannun amp minion dont try hard wont get neither vote nor socalled khalistan bo',
#  'start trend pakistan remember dr najeeb khalistan notifydecisionsofcommission payandserviceprotecti',
#  'no khalistan khai garbage dear sikh quick realise pannun',
#  'fight khalistan result mainly two thing carnage innocent people resurgence hatred soci',
#  'cm gherao modi truck rally th sept truck driver urge understand fe',
#  'cm solution farmersbill sfj khalistan register vote',
#  'cm gherao modi truck rally th sept truck drive urge reach delhi visible',
#  'start trend pakistan remember dr najeeb khalistan notifydecisionsofcommission payandserviceprotecti',
#  'stop modi target land punjab farmer solution khalistan register vote',
#  'farmer register vote october maximum register vote get grant money sfj',
#  'punjab deep sht cm talk amp behave like goongetting chakka jam rail roko do',
#  'punjab deep sht cm talk amp behave like goongetting chakka jam rail roko do',
#  'people ask khalistan',
#  'sfj gunda gang launch another application google play store which motive spread hate among sikh',
#  'sikh justice mislead sikh community name khalistan support pakistan',
#  'sikh justice mislead sikh community name khalistan support pakistan',
#  'charm hour long discussion channel president shiromani akali dal amritsar',
#  'gherao modi truck rally th sept solution khalistan justice prevail',
#  'cm gherao modi truck rally th sept not accept farmer bill solution',
#  'no way leave modi except may free kashmir vacant space way',
#  'no way leave modi except may free kashmir vacant space way khalistan',
#  'cm gherao modi truck rally th sept solution farmersbill sfj raise voic',
#  'cm capt amarinder amp power doesn',
#  'solution farmersbill khalistan cm gherao modi truck rally',
#  'solution farmersbill khalistan cm gherao modi truck rally',
#  'pannun amp minion dont try hard wont get neither vote nor socalled khalistan bo',
#  'cm gherao modi truck rally th sept solution farmersbill sfj khalistan',
#  'pannun no shame leave',
#  'cm gherao modi truck rally th sept solution farmersbill sfj khalistan',
#  'b right farmer dont take darma justice way protest live',
#  'punjab deep sht cm talk amp behave like goongetting chakka jam rail roko do',
#  'cm gherao modi truck rally th sept solution farmersbill sfj',
#  'farmer want right burn tractor not solution solution khalistan',
#  'cm gherao modi truck rally th sept solution farmersbill sfj',
#  'cm gherao modi truck rally th sept solution farmersbill sfj',
#  'pannun pakistani puppet who work pakistan see indian sikh answer referendum shame',
#  'cm get ready gherao modi truck rally campaign th sept anti farmer bill pass',
#  'cm gherao modi truck rally th sept support farmer stopmodi farmer want right live',
#  'not punjab kesari dainik jagran way far punjab day super secular',
#  'cm gherao modi truck rally th sept solution farmersbill sfj khalistan',
#  'khalistan solution farmersbill cm gherao modi truck rally th sept',
#  'fight khalistan result mainly two thing carnage innocent people resurgence hatred soci',
#  'like fail agenda pannun door door campaign go super failure nahi chahida k',
#  'b account withhold india response legal demand learn',
#  'cm u ready gherao modi truck rally watch u th sept solution',
#  'people ask khalistan',
#  'save farmer cm gherao modi truck rally th sept solution farmersbill sfj',
#  'b account withhold india response legal demand learn',
#  'b account withhold india response legal demand learn',
#  'b account withhold india response legal demand learn',
#  'b account withhold india response legal demand learn',
#  'b account withhold india response legal demand learn',
#  'charm hour long discussion channel president shiromani akali dal amritsar',
#  'way stop modi agenda cm gherao modi truck rally th sept solution',
#  'fight khalistan result mainly two thing carnage innocent people resurgence hatred soci',
#  '',
#  'sikh nation see real face not fool u anymore what',
#  'b gherao modi truck rally th sept cm dont want anything except want live l',
#  'cm get ready gherao modi truck rally campaign th sept anti farmer bill pass',
#  'cm gherao modi truck rally conduct th sept modi need sensitize punjab',
#  'sikh want khalistan sikh indian army man explain how sikh treat india minority not safe india',
#  'b support poor farmer think government see whats go try',
#  'cm gherao modi sept anti farmer bill bil increase problem p',
#  'khalistan solution leave u cm gherao modi truck rally th sept sol',
#  'punjab haryana want independent separate homeland khalistan cm gherao modi truck rally',
#  'cm make change farmer bill not solution solution farmersbill',
#  'cm gherao modi truck rally th sept solution farmersbill sfj khalistan',
#  'cm government let poor farmer fend time crisis',
#  'cm gherao modi truck rally th sept save farmer punjab haryana solution',
#  'cm gherao modi truck rally farmer systematically force suicide khalistan bnao soluti',
#  'cm gherao modi truck rally th sept solution farmersbill sfj',
#  'oops what happen video go break every khalistanis dream socalled khalistan',
#  'cm gherao modi truck rally th sept solution farmersbill sfj',
#  'b account withhold india response legal demand learn',
#  'b cm gherao modi truck rally th sept dont want anything except want live',
#  'farmer gather outside modi residence new delhi farmersbill call reform bill wil',
#  'sikh nation see real face not fool u anymore what farmersbil',
#  'sfj gunda gang launch another application google play store which motive spread hate among sikh',
#  'cm solution farmersbill sfj khalistan register vote',
#  'sikh nation see real face not fool u anymore what',
#  'b account withhold india response legal demand learn',
#  'stop crocodile tear know puppet indian government no power thing punjab farm',
#  'farmer gather outside modi residence new delhi farmersbill call reform b',
#  'cm make change farmer bill not solution solution farmersbill',
#  'stop crocodile tear know puppet indian government no power thing',
#  'b account withhold india response legal demand learn',
#  'cm get ready gherao modi truck rally campaign th sept anti farmer bill pass',
#  'cm gherao modi truck rally th sept time show modi sikh fight r',
#  'b account withhold india response legal demand learn',
#  'b trucker go reach delhi september there one solution thats farmer bill',
#  'punjab truck stop modi take justice gherao modi truck rally th sept solution farmersbill',
#  'no khalistan khai garbage dear sikh quick realise pannun',
#  'cm farmer bad debt not pay loan solution',
#  'part rally save life ppor farmer stop enter cm gherao modi',
#  'no khalistan khai garbage dear sikh quick realise pannun',
#  'b account withhold india response legal demand learn',
#  'ready gherao modi truck rally th september punjab haryana people want live independent life',
#  'khalistan zindabad modi let ur agenda',
#  'sept truck rally day gherao modi solution farmersbill sfj khalistan',
#  'people ask khalistan',
#  'no khalistan khai garbage dear sikh quick realise pannun',
#  'sikh want khalistan sikh indian army man explain how sikh treat india minority not safe india',
#  'pakistan eliminate sikh population decade kill rape abduction force marriage',
#  'b account withhold india response legal demand learn',
#  'b account withhold india response legal demand learn',
#  'fight khalistan result mainly two thing carnage innocent people resurgence hatred soci',
#  'cm disquiet not solution solution farmersbill sfj',
#  'cm farmer bad debt not pay loan solution th',
#  'b cm dont fake don',
#  'cm amendment farmer bill not solution solution',
#  'cm make change farmer bill not solution solution',
#  'cm farmer bad debt not pay loan solution',
#  'b cm dont want bill want khalistan soluti',
#  'cm make change farmer bill not solution',
#  'cm farmer bad debt not pay loan solution',
#  'cm farmer commit suicide avoid pay loan solution',
#  'cm make change farmer bill not solution',
#  'cm solution farmersbill sfj khalistan register vote',
#  'sfj gunda gang launch another application google play store which motive spread hate among sikh',
#  'b account withhold india response legal demand learn',
#  'cm farmer bad debt not pay loa',
#  'cm capt amarinder amp power doesn',
#  'b account withhold india response legal demand learn',
#  'b cm indian government isnt actually sincere poor farmer say yes',
#  'b account withhold india response legal demand learn',
#  'b cm dont fake don',
#  'cm yearly farmer take life avoid pay loan soluti',
#  'seperate state khalistan need sikh farmer not save',
#  'cm protest not solution want land solution farmersbill',
#  'cm solution farmersbill sfj khalistan register vote',
#  'cm make change farmer bill not solution solution',
#  'b cm dont fake don',
#  'cm protest not solution solution',
#  'cm disquiet not solution solution farmersbill',
#  'cm gherao modi truck rally th sept solution farmersbill sfj khalistan',
#  'sfj gunda gang launch another application google play store which motive spread hate among sikh',
#  'hope not plan promote khalistan movement',
#  'sfj gunda gang launch another application google play store which motive spread hate among sikh',
#  'no khalistan khai garbage dear sikh quick realise pannun',
#  'cm gherao modi truck rally th sept solution farmersbill sfj khalistan',
#  'cm gherao modi truck rally th sept solution farmersbill sfj khalistan',
#  'cm solution separate land farmersbill sfj khalistan',
#  'cm make change farmer bill not solution solution',
#  'cm make change farmer bill not solution sol',
#  'cm not believe word solution',
#  'b cm dont want anything except want live life',
#  'b account withhold india response legal demand learn',
#  'cm gherao modi truck rally th sept solution farmersbill sfj khalistan',
#  'cm gherao modi truck rally th sept solution farmersbill sfj khalistan',
#  'cm gherao modi truck rally th sept solution farmersbill sfj khalistan',
#  'farmersbill allready supressed fa',
#  'cm farmer bad debt not',
#  'b cm every life important cruelty isnt',
#  'want farmer commit suicide farmersbill',
#  'b cm dont fake don',
#  'sikh want khalistan sikh indian army man explain how sikh treat india minority not safe india',
#  'b cm dont make false prom',
#  'b cm dont fake yo',
#  'sfj gunda gang launch another application google play store which motive spread hate among sikh',
#  'sto',
#  'cm gherao modi truck rally th sept solution farmersbill sfj khalistan',
#  '',
#  'oops what happen video go break every khalistanis dream socalled khalistan',
#  'cm',
#  'cm',
#  '',
#  'solution problem khalistan',
#  'want farmer commit suicide due kind anti farmer bill want',
#  'outrightly reject ideology separatism clear crystal khalistan ideology cannot',
#  'protest not solution solution farmersbill sfj khalistan',
#  'farmer commit suicide punjab still pass law what',
#  'b account withhold india response legal demand learn',
#  'sfj gunda gang launch another application google play store which motive spread hate among sikh',
#  'fight khalistan result mainly two thing carnage innocent people resurgence hatred soci',
#  'capt amarinder amp power doesn',
#  'b dont want anything except want live life way don',
#  'sikh nation decide future khalistan make one day',
#  'b why cry',
#  'say no lollipop what farmersbill',
#  'cm stop showoff don',
#  'cm protest not solution solution',
#  'b account withhold india response legal demand learn',
#  'farmer live miserable life want khalistan farmersbill sfj',
#  'stop crocodile tear know puppet indian government no po',
#  'guyz not sincere sikh nation right khalistan',
#  'say yes khalistan solution problem sfj farmersbill',
#  'cm create drama nothing farmer gherao modi truck rally th sept solution',
#  'nothing u what right u futur',
#  'sfj gunda gang launch another application google play store which motive spread hate among sikh',
#  'cm gherao modi truck rally th sept support poor farmer stop modi solution farmersbill',
#  'cm gherao modi truck rally th sept solution farmersbill sfj khalistan',
#  'sikh want khalistan sikh indian army man explain how sikh treat india minority not safe india',
#  'cm gherao modi truck rally th sept solution farmersbill sfj khalistan',
#  'oops what happen video go break every khalistanis dream socalled khalistan',
#  'fight khalistan result mainly two thing carnage innocent people resurgence hatred soci',
#  'cm gherao modi truck rally th sept solution farmersbill sfj khalistan',
#  'cm gherao modi truck rally th sept solution farmersbill sfj khalistan',
#  'farmer protest ambala army cavalcade block pro khalistan slogan raise cavalcade ar',
#  'b account withhold india response legal demand learn',
#  'time cm gherao modi truck rally th sept solution farmersbill sfj khalistan regist',
#  'cm gherao modi truck rally th sept solution farmersbill sfj khalistan',
#  'sikh want khalistan sikh indian army man explain how sikh treat india minority not safe india',
#  'like fail agenda pannun door door campaign go super failure nahi chahida k',
#  'b time cm gherao modi truck rally th sept solution farmersbill sfj khalistan',
#  'sikh want khalistan sikh indian army man explain how sikh treat india minority not safe india',
#  'sikh want khalistan sikh indian army man explain how sikh treat india minority not safe india',
#  'sikh want khalistan sikh indian army man explain how sikh treat india minority not safe india',
#  'mr pannun door door campaign go super failure like campaign nah',
#  'fight khalistan result mainly two thing carnage innocent people resurgence hatred soci',
#  'cm gherao modi truck rally th sept solution farmersbill sfj khalistan',
#  'like fail agenda pannun door door campaign go super failure nahi chahida k',
#  'sikh want khalistan sikh indian army man explain how sikh treat india minority not safe india',
#  'sikh want khalistan sikh indian army man explain how sikh treat india minority not safe india',
#  'sikh want khalistan sikh indian army man explain how sikh treat india minority not safe india',
#  'sikh want khalistan sikh indian army man explain how sikh treat india minority not safe india',
#  'no khalistan khai garbage dear sikh quick realise pannun',
#  'sikh want khalistan sikh indian army man explain how sikh treat india minority not safe india',
#  'sikh want khalistan sikh indian army man explain how sikh treat india minority not safe india',
#  'b account withhold india response legal demand learn',
#  'cm gherao modi truck rally th sept solution farmersbill sfj khalistan',
#  'sfj gunda gang launch another application google play store which motive spread hate among sikh',
#  'sikh want khalistan sikh indian army man explain how sikh treat india minority not safe india',
#  'pannun please grow stop woo sikh community terror money real sikh not weak gree',
#  'why sf j late program rail roko big flop show no sikh ever interest join sf j khalistan',
#  'sfj gunda gang launch another application google play store which motive spread hate among',
#  'no khalistan khai garbage dear sikh quick realise pannun',
#  'no khalistan khai garbage dear sikh quick realise pannun',
#  'oops what happen video go break every khalistanis dream socalled khalistan',
#  'sikh want khalistan sikh indian army man explain how sikh treat india minority not safe india',
#  'like fail agenda pannun door door campaign go super failure nahi chahida k',
#  'cm gherao modi truck rally th sept solution farmersbill sfj khalistan',
#  'fight khalistan result mainly two thing carnage innocent people resurgence hatred soci',
#  'oops what happen video go break every khalistanis dream socalled khalistan',
#  'cm gherao modi truck rally th sept solution farmersbill sfj khalistan',
#  'fight khalistan result mainly two thing carnage innocent people resurgence hatred soci',
#  'oops what happen video go break every khalistanis dream socalled khalistan',
#  'no khalistan khai garbage dear sikh quick realise pannun',
#  'sikh want khalistan sikh indian army man explain how sikh treat india minority not safe india',
#  'like fail agenda pannun door door campaign go super failure nahi chahida k',
#  'fight khalistan result mainly two thing carnage innocent people resurgence hatred soci',
#  'no khalistan khai garbage dear sikh quick realise pannun',
#  'oops what happen video go break every khalistanis dream socalled khalistan',
#  'oops what happen video go break every khalistanis dream socalled khalistan',
#  'oops what happen video go break every khalistanis dream socalled khalistan',
#  'sikh want khalistan sikh indian army man explain how sikh treat india minority not safe india',
#  'basically pannun try hard make maximum money november know what khalistan alread',
#  'cm gherao modi truck rally th sept solution farmersbill sfj khalistan',
#  'oops what happen video go break every khalistanis dream socalled khalistan',
#  'pannun khalistani stooge also say dont want support khalistan terror drama',
#  '',
#  'charm hour long discussion channel president shiromani akali dal amritsar',
#  'sikh want khalistan sikh indian army man explain how sikh treat india minority not safe india',
#  'cm gherao modi truck rally th sept solution farmersbill sfj khalistan',
#  'b account withhold india response legal demand learn',
#  'b account withhold india response legal demand learn',
#  'sikh want khalistan sikh indian army man explain how sikh treat india minority not safe india',
#  'sikh want khalistan sikh indian army man explain how sikh treat india minority not safe india',
#  'cm gherao modi truck rally th sept solution farmersbill sfj khalistan',
#  'sikh want khalistan sikh indian army man explain how sikh treat india minority not safe india',
#  'sikh want khalistan sikh indian army man explain how sikh treat india minority not safe india',
#  'sikh want khalistan sikh indian army man explain how sikh treat india minority not safe india',
#  'sikh want khalistan sikh indian army man explain how sikh treat india minority not safe india',
#  'like fail agenda pannun door door campaign go super failure nahi chahida k',
#  'sikh want khalistan sikh indian army man explain how sikh treat india minority not safe india',
#  'sikh want khalistan sikh indian army man explain how sikh treat india minority not safe',
#  'cm gherao modi truck rally th sept solution farmersbill sfj khalistan',
#  'cm gherao modi truck rally th sept solution farmersbill sfj khalistan',
#  'b account withhold india response legal demand learn',
#  'charm hour long discussion channel president shiromani akali dal amritsar',
#  'b account withhold india response legal demand learn',
#  'fight khalistan result mainly two thing carnage innocent people resurgence hatred soci',
#  'like fail agenda pannun door door campaign go super failure nahi chahida k',
#  'sikh amp muslim minority india want freedom india community realize elder',
#  'mr pannun door door campaign go super failure like campaign',
#  'know someone hijack issue farm bill amp run agenda kisaan union cannot survive without',
#  'oops what happen video go break every khalistanis dream socalled khalistan',
#  'like fail agenda pannun door door campaign go super failure nahi chahida k',
#  'fight khalistan result mainly two thing carnage innocent people resurgence hatred soci',
#  'like fail agenda pannun door door campaign go super failure',
#  'charm hour long discussion channel president shiromani akali dal amritsar',
#  'government panjab busy resolution caa nose pro khalistan really',
#  'socalled pure country call pakistan kill murder blast commute inhuman atrocity thei',
#  'people ask khalistan',
#  'fight khalistan result mainly two thing carnage innocent people resurgence hatred soci',
#  'people ask khalistan',
#  'fight khalistan result mainly two thing carnage innocent people resurgence hatred soci',
#  'bs hun hor ni way',
#  'bs hun hor ni way',
#  'bs hun hor ni way',
#  'sfj conduct referendum different place india amp fail miserably everywhere nw team pannu h come ne',
#  'bs hun hor ni way',
#  'bs hun hor ni way',
#  'fight khalistan result mainly two thing carnage innocent people resurgence hatred soci',
#  'charm hour long discussion channel president shiromani akali dal amritsar',
#  'oops what happen video go break every khalistanis dream socalled khalistan',
#  'oops what happen video go break every khalistanis dream socalled khalistan',
#  'pannun pakistani puppet who work pakistan see indian sikh answer referendum shame',
#  'fight khalistan result mainly two thing carnage innocent people resurgence hatred soci',
#  'fight khalistan result mainly two thing carnage innocent people resurgence hatred soci',
#  'charm hour long discussion channel president shiromani akali dal amritsar',
#  'what would call video watch tight slap dose humiliation sfj khalistani separ',
#  'oops what happen video go break every khalistanis dream socalled khalistan',
#  'no khalistan khai garbage dear sikh quick realise pannun',
#  'thousand indian farmer protest agriculturerelated bill sikh justice sfj try fi',
#  'pannun actual status socalled khalistan referendum vote still want doo',
#  'oops what happen video go break every khalistanis dream socalled khalistan',
#  'dear sfj pannun khalistan supporter please answer question ask video stop kha',
#  'no khalistan khai garbage dear sikh quick realise pannun',
#  'pannun no shame leave',
#  'pakistan',
#  'fight khalistan result mainly two thing carnage innocent people resurgence hatred soci',
#  'pannun pakistani puppet who work pakistan see indian sikh answer referendum shame',
#  'november terror attack premise sant nirankari mission indian state punjab',
#  'dear pannun bhai listen recent debate also feel how khalistan which not',
#  'oops what happen video go break every khalistanis dream socalled khalistan',
#  'fight khalistan result mainly two thing carnage innocent people resurgence hatred soci',
#  'hey pannun why',
#  'thousand indian farmer protest agriculturerelated bill sikh justice sfj try',
#  'fight khalistan result mainly two thing carnage innocent people resurgence hatred soci',
#  'farmer protest ambala army cavalcade block pro khalistan slogan raise cavalcade ar',
#  'b farmer protest ambala army cavalcade block pro khalistan slogan raise cavalcade',
#  'fight khalistan result mainly two thing carnage innocent people resurgence hatred soci',
#  'charm hour long discussion channel president shiromani akali dal amritsar',
#  'oops what happen video go break every khalistanis dream socalled khalistan',
#  'no khalistan khai garbage dear sikh quick realise pannun',
#  'oops what happen video go break every khalistanis dream socalled khalistan',
#  'fight khalistan result mainly two thing carnage innocent people resurgence hatred soci',
#  'what would call video watch tight slap dose humiliation sfj khalistani separ',
#  'fight khalistan result mainly two thing carnage innocent people resurgence hatred soci',
#  'charm hour long discussion channel president shiromani akali dal amritsar',
#  'oops what happen video go break every khalistanis dream socalled khalistan',
#  'no khalistan khai garbage dear sikh quick realise pannun',
#  'fight khalistan result mainly two thing carnage innocent people resurgence hatred soci',
#  'b bhene isnt khalistan guru sahiban talk khalsa raj mean something much much good',
#  'b miss aint khalistan agenda name sikh suppose dont know wh',
#  'b isnt khalistan agenda name religion take look',
#  'oops what happen video go break every khalistanis dream socalled khalistan',
#  'fight khalistan result mainly two thing carnage innocent people resurgence hatred soci',
#  'no khalistan khai garbage dear sikh quick realise pannun',
#  'oops what happen video go break every khalistanis dream socalled khalistan',
#  'b what khalistan tell please twitter',
#  'fight khalistan result mainly two thing carnage innocent people resurgence hatred soci',
#  'oops what happen video go break every khalistanis dream socalled khalistan',
#  'fight khalistan result mainly two thing carnage innocent people resurgence hatred soci',
#  'no khalistan khai garbage dear sikh quick realise pannun',
#  'what would call video watch tight slap dose humiliation sfj khalistani separ',
#  'fight khalistan result mainly two thing carnage innocent people resurgence hatred soci',
#  'no khalistan khai garbage dear sikh quick realise pannun',
#  'oops what happen video go break every khalistanis dream socalled khalistan',
#  'fight khalistan result mainly two thing carnage innocent people resurgence hatred soci',
#  'no khalistan khai garbage dear sikh quick realise pannun',
#  'fight khalistan result mainly two thing carnage innocent people resurgence hatred soci',
#  'no khalistan khai garbage dear sikh quick realise pannun',
#  'oops what happen video go break every khalistanis dream socalled khalistan',
#  'fight khalistan result mainly two thing carnage innocent people resurgence hatred soci',
#  'b oops what happen video go break every khalistanis dream socalled khalistan',
#  'fight khalistan result mainly two thing carnage innocent people resurgence hatred',
#  'what would call video watch tight slap dose humiliation sfj khalistani separ',
#  'what would call video watch tight slap dose humiliation sfj khalistani separ',
#  'what would call video watch tight slap dose humiliation sfj khalistani separ',
#  'charm hour long discussion channel president shiromani akali dal amritsar',
#  'charm hour long discussion channel president shiromani akali dal amritsar',
#  'entire india along indian sikh community outrightly reject demand khalistan illeg',
#  'pannun no shame leave',
#  'pannun no shame leave',
#  'pannun amp minion dont try hard wont get neither vote nor socalled khalistan bo',
#  'shame khalistani supporter whoever do no right stay punjab request leave ou',
#  'pannun know mean no word no usually use give negative response real sikh say big',
#  'mil macdonald laurier institute report note clear who really drive khalistan bus pakistan',
#  'picture show pannun pakistani sponsor make khalistan referendum twitter r',
#  'one want khalistan entire india khalistan hemkund north rameshwaram south barcha',
#  'charm hour long discussion channel president shiromani akali dal amritsar',
#  'charm hour long discussion channel president shiromani akali dal amritsar',
#  'charm hour long discussion channel president shiromani akali dal amritsar',
#  'pannun not listen real sikh imaginary world doesnt care sikh community',
#  'pannun part peaceful campaign khalistan socalled peaceful campaign khalistan n',
#  'charm hour long discussion channel president shiromani akali dal amritsar',
#  'sikh amp muslim minority india want freedom india community realize elder',
#  'entire india along indian sikh community outrightly reject demand khalistan illeg',
#  'b dear indian dont worry nagaland khalistan atarprdas remember ladakh',
#  'socalled pure country call pakistan kill murder blast commute inhuman atrocity thei',
#  'punjab amp haryana people protest modi un watch live khalistan sfj',
#  'sfj protest modi un watch live meet shoe shout berate right',
#  'khalistan street new york punjab protest modi un watch live',
#  'punjab new york punjab farmer protest modi un butch heart always disrupt life pe',
#  'khalistan protest modi watch live punjab farmer',
#  '',
#  '',
#  'sfj conduct referendum different place india amp fail miserably everywhere nw team pannu h come ne',
#  'b india sikh expose modis face new york occasion world world meet outside un see',
#  '',
#  'b',
#  'one genuinely feel farmer don',
#  'pannun no shame leave',
#  'canadian thinktank recently publish report which argue khalistan separatist movement project',
#  'sfj sikh protest modi un policy punjab farmer khalistan referendum',
#  'don',
#  'what would call video watch tight slap dose humiliation sfj khalistani separ',
#  'entire india along indian sikh community outrightly reject demand khalistan illeg',
#  'khalistan sfj modi un punjab farmer khalistan referendum punjab farmer life farmer become misera',
#  'b account withhold india response legal demand learn',
#  'b account withhold india response legal demand learn',
#  'b n sop khalistan punjabi jmb tag bengali isi south indian maratha unknown gro',
#  'unemployment drug waterrelated issue force sikh farmer commit suicide every indian citizen must stand',
#  'what would call video watch tight slap dose humiliation sfj khalistani separ',
#  'back dude kashmir khalist',
#  'back dude kashmir',
#  'petition file delhi high court seek criminal action representative',
#  'fake sikh who nr live outside create disharmony among sikh community terror plan khal',
#  'punjab haryana epicentre nationwide protest farmer sfj khalistan gherao modi',
#  'thousand farmer block road highway several state sfj khalistan gherao modi bharat bandh',
#  'what would call video watch tight slap dose humiliation sfj khalistani separ',
#  'exclusive break news khalistani supporter video show khalistan not subject',
#  'b account withhold india response legal demand learn',
#  'b account withhold india response legal demand learn',
#  'b account withhold india response legal demand learn',
#  'book river fire khalistan struggle narrative sikh militant struggle here video presentation summarize',
#  'canadian thinktank recently publish report which argue khalistan separatist movement proj',
#  'entire india along indian sikh community outrightly reject demand khalistan illeg',
#  'b haa haa correct wont share map chutspastan wont say word',
#  'pannun amp minion dont try hard wont get neither vote nor socalled khalistan bo',
#  'petition file delhi high court seek criminal action representative',
#  'take action khalistani separatist keep electoral politics sensitive matter khalistan',
#  'pannun part peaceful campaign khalistan socalled peaceful campaign khalistan n',
#  'khalistan voter registration drive freedom drive referendum solution khalistan solution punja',
#  'why sf j late program rail roko big flop show no sikh ever interest join sf j khalistan',
#  'petition file delhi high court seek criminal action representative',
#  'petition file delhi high court seek criminal action representative',
#  'khalistan never form one thing sure pakistan break soon think pakistani punja',
#  'khalistan issue make moneymaking industry western country set people who basically fra',
#  'khalistan voter registration drive freedom drive referendum solution khalistan solution punja',
#  'dear sikh community hope aware gurpatwant singh pannun go mad terrorist plan',
#  'sfj prove organisation run brainless people fake tik tok account which no video',
#  'yes pannun place khalistan khalistan idea go straignt hell belong',
#  'haven',
#  'sfj must appeal twitter bandh khalistani pak isi account sikh feed',
#  'akali dal desh drohi since parkash badal take meticulous plan make punjab separ',
#  'people support khalistan referendum gimmick gang hardly concern',
#  'khalistan voter registration drive freedom drive referendum solution khalistan solution punja',
#  'pannun part peaceful campaign khalistan socalled peaceful campaign khalistan n',
#  'khalistan poster see everywhere pakistan see different stage set spread hatred',
#  'khalistan voter registration drive freedom drive referendum solution khalistan solution punja',
#  'petition file delhi high court seek criminal action representative',
#  'pakistani friend start assume indian punjabi especially sikh arent happy country l',
#  'fake pak bot never understand truth dont brain handle truth photo',
#  'pannun bhai always want great khalistan well know pakistan big portion',
#  'take action khalistani separatist keep electoral politics sensitive matter khalistan',
#  'khalistan voter registration drive freedom drive referendum solution khalistan solution punja',
#  'indian sikh not agree idea khalistan understand idea referendum base ar',
#  'sikh community pakistan not get justice khalistan pakistan pak sikh support esta',
#  'pannun part peaceful campaign khalistan socalled peaceful campaign khalistan n',
#  'pak sikh request raise voice khalistan th august independence day pakistan nankana',
#  'take action khalistani separatist keep electoral politics sensitive matter khalistan',
#  'evil plan khalistan never successful not even dream man liar mu',
#  'khalistan doesnt even exist social medium pak bot how much proof need understand pann',
#  'british sikh association defy sikh federation uk demand independent khalistan sikh',
#  'which angle broke look like sikh name gurpatwant singh pannun accumulate huge wealth',
#  'fake sikh who nr live outside create disharmony among sikh community terror plan khal',
#  'pannun part peaceful campaign khalistan socalled peaceful campaign khalistan n',
#  'exactly khalistanis use social medium platform spread hate promote separatist propaganda',
#  'message give comfort people understand sikh dont want khalistan jus',
#  'future referendum khalistan perfectly depict cartoon khalistan imply fill blank',
#  'idea khalistan bear hatred idea bear hate violence doesnt really help anybody how c',
#  'khalistan never form exist imagination anti india element support pakistan',
#  'real sikh resist online khalistan campaign get rid pakbacked moron who',
#  'notice slap face khalistani supporter who help sfj pannun spread hate na',
#  'say loud clear support lord ramus ranger cbe one who understand pain anger',
#  'khalistan khalistan voter registration drive freedom drive referendum solution khalistan',
#  'khalistan voter registration drive freedom drive referendum solution khalistan solution punja',
#  'khalistan voter registration drive freedom drive referendum solution khalistan solution',
#  'khalistan voter registration drive freedom drive referendum solution khalistan solution',
#  'what think psychology people who support khalistan issue give sense',
#  'literally people frame people khalistanis live show tube wow im',
#  'may leave nda prakashsinghbadal respect balasahebthackeray',
#  'petition file delhi high court seek criminal action representative',
#  'what firstly paksponsored stooge protest irrational demand khalistan secondly ind',
#  'two dumb khalistanis best next pannun',
#  'voter registration drive freedom drive referendum solution khalistan solution',
#  'voter registration drive freedom drive referendum solution khalistan soluti',
#  'voter registration drive freedom drive referendum solution khalistan soluti',
#  'voter regis',
#  'voter registration drive freedom drive referendum solution khalistan',
#  'petition file delhi high court seek criminal action representative',
#  'pannun make khalistan no objective every person whether sikh non sikh aware',
#  'khalistan voter registration drive freedom drive referendum solution khalistan solution',
#  'enlighten note sikh gurpatwant singh pannun not able make khalistan try',
#  'sikh make sure khalistan never become reality thats not what guru want',
#  'nation state form around religious identity highly problematic doom fail practically sikh li',
#  'shame sfj amp pannun who want divide sikh panth objective make khalistan always remain fanta',
#  'early generation suffer lot due khalistani terrorism why would want live li',
#  'sikh different ideology hindu cant nation referendum solution khalistan solution',
#  'what would call video watch tight slap dose humiliation sfj khalistani separ',
#  'british sikh association defy sikh federation uk demand independent khalistan sikh',
#  'khalistan doesnt even exist social medium pak bot how much proof need understand pann',
#  'pannun part peaceful campaign khalistan socalled peaceful campaign khalistan n',
#  'petition file delhi high court seek criminal action representative',
#  'khalistanis dont use brain dont photo say found father khalistan movement',
#  'what would call video watch tight slap dose humiliation sfj khalistani separ',
#  'well young sikh totally reject idea khalistan no historical validity no root reli',
#  'reality reality pakis not happy sikh community live happily india reality',
#  'take action khalistani separatist keep electoral politics sensitive matter khalistan',
#  'take action khalistani separatist keep electoral politics sensitive matter',
#  'quick question neighbour pakistan what status khalistan pakistan how many vote collect',
#  'khalistan referendum campaign front un ny watch live guy support khalistan referendum khalistan',
#  'petition file delhi high court seek criminal action representative',
#  'what would call video watch tight slap dose humiliation sfj khalistani separ',
#  'pakistan smuggle drug weapon counterfeit currency indian punjab firozpur pathankot',
#  'petition file delhi high court seek criminal action representative',
#  'khalistan voice sikh never forget indian state kill sikh chatti sing hpora',
#  'petition file delhi high court seek criminal action representative',
#  'pannun part peaceful campaign khalistan socalled peaceful campaign khalistan n',
#  'petition file delhi high court seek criminal action representative',
#  'petition file delhi high court seek criminal action representative',
#  'entire india along indian sikh community outrightly reject demand khalistan illeg',
#  'petition file delhi high court seek criminal action representative',
#  'petition file delhi high court seek criminal action representative',
#  'petition file delhi high court seek criminal action represe',
#  'pannun part peaceful campaign khalistan socalled peaceful campaign khalistan n',
#  'think defeat khalistan pay article fake propaganda india al',
#  'think defeat khalistan pay article fake propaganda india al',
#  'pannun part peaceful campaign khalistan socalled peaceful campaign khalistan n',
#  'entire india along indian sikh community outrightly reject demand khalistan illeg',
#  'khalistan voice sikh never forget indian state kill sikh chatti sing hpora',
#  'pannun part peaceful campaign khalistan socalled peaceful campaign khalistan n',
#  'entire india along indian sikh community outrightly reject demand khalistan illeg',
#  'pannun part peaceful campaign khalistan socalled peaceful campaign khalistan n',
#  'pannun part peaceful campaign khalistan socalled peaceful campaign khalistan n',
#  'khalistan voice sikh never forget indian state kill sikh chatti sing hpora',
#  'pannun part peaceful campaign khalistan socalled peaceful campaign khalistan n',
#  'pannun part peaceful campaign khalistan socalled peaceful campaign khalistan n',
#  'pannun part peaceful campaign khalistan socalled peaceful campaign khalistan',
#  'khalistan voice sikh never forget indian state kill sikh chatti sing hpora',
#  'khalistan voice sikh never forget indian state kill sikh chatti sing hpora',
#  'khalistan voice sikh never forget indian state kill sikh chatti sing hpora',
#  'khalistan voice sikh never forget indian state kill sikh chatti sing hpora',
#  'khalistan voice sikh never forget indian state kill sikh chatti sing hpora',
#  'entire india along indian sikh community outrightly reject demand khalistan illeg',
#  'punjab politician either give u freedom take cut agri biz support khalistan',
#  'think defeat khalistan pay article fake propaganda india always',
#  'indian sikh youth need b vigilant amp nt fall trap desperate khalistanis back pakistan failure p',
#  'basically pannun try hard make maximum money november know what khalistan alread',
#  'sfj khalistani separatist upload another application google play store promote khalistan goal',
#  'khalistan peaceful democratic right sikh last decade kill',
#  'khalistan voice sikh never forget indian state kill sikh chatti sing hp',
#  'khalistan voice sikh never forget indian state kill sikh chatti sing hpora',
#  'khalistan voice sikh never forget indian state kill sikh chatti sin',
#  'khalistan voice sikh never forget indian state kill sikh chatti sin',
#  'khalistan voice sikh never forget indian state kill sikh chatti sing hpora',
#  'khalistan voice sikh never forget indian state kill sikh chatti sing hpora',
#  'khalistan referendum campaign front un ny watch live guy support khalistan referendum khalistan',
#  'b account withhold india response legal demand learn',
#  'khalistan voice sikh never forget indian state kill sikh chatti sing hpora',
#  'entire india along indian sikh community outrightly reject demand khalistan illeg',
#  'khalistan voice sikh never forget indian state kill sikh chatti sing hpora',
#  'pannun not listen real sikh imaginary world doesnt care sikh community',
#  'khalistan voice sikh never forget indian state kill sikh chatti sing hpora',
#  'entire india along indian sikh community outrightly reject demand khalistan illeg',
#  'entire india along indian sikh community outrightly reject demand khalistan illeg',
#  'entire india along indian sikh community outrightly reject demand khalistan illeg',
#  'khalistan voice sikh never forget indian state kill sikh chatti sing hpora',
#  'entire india along indian sikh community outrightly reject demand khalistan illeg',
#  'pannun amp minion dont try hard wont get neither vote nor socalled khalistan bo',
#  'shame khalistani supporter whoever do no right stay punjab request leave ou',
#  'khalistan voice sikh never forget indian state kill sikh chatti sing hpora',
#  'khalistan voice sikh never forget indian state kill sikh chatti sing hpora',
#  'fake sikh who nr live outside create disharmony among sikh community terror plan khal',
#  'khalistan voice sikh never forget indian state kill sikh chatti sing hpora',
#  'khalistan voice sikh never forget indian state kill sikh chatti sing hpora',
#  'khalistan voice sikh never forget indian state kill sikh chatti sin',
#  'entire india along indian sikh community outrightly reject demand khalistan illeg',
#  'entire india along indian sikh community outrightly reject demand khalistan illeg',
#  'fake sikh who nr live outside create disharmony among sikh community terror plan khal',
#  'entire india along indian sikh community outrightly reject demand khalistan illeg',
#  'land kashmir',
#  'entire india along indian sikh community outrightly reject demand khalistan illeg',
#  'entire india along indian sikh community outrightly reject demand khalistan illeg',
#  'entire india along indian sikh community outrightly reject demand khalistan illeg',
#  'entire india along indian sikh community outrightly reject demand khalistan illeg',
#  'entire india along indian sikh community outrightly reject demand khalistan illeg',
#  'khalistan referendum campaign front un ny watch live guy support khalistan referendum khalistan',
#  'entire india along indian sikh community outrightly reject demand khalistan illeg',
#  'entire india along indian sikh community outrightly reject demand khalistan il',
#  'what would call video watch tight slap dose humiliation sfj khalistani separ',
#  'khalistan referendum campaign front un ny watch live guy support khalistan referendum khalistan',
#  'what would call video watch tight slap dose humiliation sfj khalistani separ',
#  'start trend pakistan remember dr najeeb khalistan notifydecisionsofcommission payandserviceprotecti',
#  'what would call video watch tight slap dose humiliation sfj khalistani separ',
#  'fake sikh who nr live outside create disharmony among sikh community terror plan khal',
#  'what would call video watch tight slap dose humiliation sfj khalistani separ',
#  'khalistan sikh support punjab farmer protest modi punjab newyork support poor farmar khalistan r',
#  'khalistan sfj modi un punjab farmer khalistan referendum punjab farmer life farmer become misera',
#  'khalistan sikh support punjab farmer protest modi punjab newyork support poor farmar',
#  'sfj distribute million st oct th oct farmer punjab haryana register vote',
#  'vote khalistan referendum punjabi farmer live peace punjab register vote khalistan http',
#  'b account withhold india response legal demand learn',
#  'fake sikh who nr live outside create disharmony among sikh community terror plan khal',
#  'pannun pakistani puppet who work pakistan see indian sikh answer referendum shame',
#  'fake sikh who nr live outside create disharmony among sikh community terror plan khal',
#  'what would call video watch tight slap dose humiliation sfj khalistani separ',
#  'what would call video watch tight slap dose humiliation sfj khalistani separ',
#  'sikh indian army full interview fascinate conversation singh retd regard india c',
#  'akali dal desh drohi since parkash badal take meticulous plan make punjab',
#  'what would call video watch tight slap dose humiliation sfj khalistani separ',
#  'khalistan referendum campaign front un ny watch live guy support khalistan referendum khalistan',
#  'khalistan referendum campaign front un ny watch live guy support khalistan referendum khalistan',
# ...
#  'not sure why many handl',
#  'stop modi seize land punjab farmer time save farmer punjab haryana b',
#  'b sfj protest modi un let stand raise voice injustice do punjab farmer want',
#  'one genuinely feel farmer don',
#  'start trend pakistan remember dr najeeb khalistan notifydecisionsofcommission payandserviceprotection year cns',
#  '',
#  'punjabland sfj khalistan punjabfarmers not men also woman teenager protest farmer',
#  'b people haryana punjab special punjab farmer protest modi modi un policy',
#  'pm modi prove',
#  'stand punjab farmer khalistan sfj modi un punjab farmer khalistan referendum',
#  'khalistanis high spirit khalistan sfj modi un punjab farmer khalistan referendum',
#  'raise voice punjab farmer khalistan sfj modi un punjab farmer khalistan referendum',
#  'protest modi khalistan khalistan sfj modi un punjab farmer khalistan referendum',
#  'khalistan referendum campaign front un ny watch live guy support khalistan referendum khalistan',
#  'khalistan protest modi stand punjab farmer sfj khalistan referendum india divert',
#  'khalistan protest modi stand punjab farmer sfj khalistan referendum government pro',
#  'khalistan protest modi stand punjab farmer sfj khalistan referendum good live condi',
#  'mean like nagaland manipur mezoram amp khalistan',
#  'modi push farm bill amid huge opposition stop enter truck entry punjab haryana want',
#  'khalistan protest modi stand punjab farmer sfj khalistan referendum sikhism separat',
#  'khalistan protest modi stand punjab farmer sfj khalistan referendum election india w',
#  'khalistan protest modi stand punjab farmer sfj khalistan referendum sikh not c',
#  'khalistan referendum campaign front un ny watch live guy support khalistan referendum khalistan',
#  'khalistan protest modi stand punjab farmer sfj khalistan referendum india always tre',
#  'khalistan protest modi stand punjab farmer sfj khalistan referendum place worshi',
#  'live coverage protestors khalistan sfj modi un punjab farmer khalistan referendum',
#  'modi please pity u punjabfarmers protest modi khalistan punjabfarmers wattch',
#  'punjab haryana people protest modi khalistan punjabfarmers watch livexe',
#  'b sfj protest modi un let stand raise voice injustice do punjab farmer want',
#  'sfj protest modi un poor punjab farmer mr modi not treat minority well',
#  'modi grab land farmer amp deprive basic right first sikh punjab farmer',
#  'money plz don',
#  'stand khalistan khalistan protest modi khalistan sfj modi un punjab farmer',
#  'live coverage protestors khalistan protest modi khalistan sfj modi un punjab farmer',
#  'khalistanis high spirit sfj modi un punjab farmer khalistan referendum khalistan protest',
#  'modi grab land farmer amp deprive basic right first sikh punjab farmer',
#  'b stop modi grab land punjab farmer land mother amp source income poor farmer cant surviv',
#  'freedom demand struggle stand punjab farmer khalistan sfj modi un punjab farmer',
#  'raise voice punjab farmer khalistan protest modi khalistan modi un punjab farmer',
#  'live coverage protestors khalistan sfj modi un punjab farmer khalistan referendum',
#  'protest modi khalistan khalistan referendum',
#  'khalistanis high spirit khalistan sfj modi un punjab farmer khalistan referendum',
#  'stop modi grab land punjab farmer stop enter truck sfj help u get rid injustice',
#  'stand punjab farmer watch live coverage sfj modi un punjab farmer',
#  'protestors great watch live coverage khalistan sfj modi un punjab farmer',
#  'khalistan protest modi un watch live farmer raise fo',
#  'b modi instead ask blame everyone why dont u something stop unfair ar',
#  'b account withhold india response legal demand learn',
#  'b account withhold india response legal demand learn',
#  'b account withhold india response legal demand learn',
#  'b account withhold india response legal demand learn',
#  'b account withhold india response legal demand learn',
#  'b modi un dont bother listen problem punjab farmer effect call',
#  'pakistan around partition weve never see photograph colour ehsan rehan first photograph gurdwara',
#  'sfj call sikh protest modi un policy punjab farmer khalistan referendum',
#  'sikh protest modi raise voice punjab farmer get justice khalistan',
#  'sfj protest modi un poor punjab farmer mr modi not treat minority well',
#  'fail leader try blame someone elect modi india fail take stone age stop modi',
#  'khalistan sfj modi un punjab farmer khalistan referendum stand right',
#  'khalistanis high spirit khalistan sfj modi un punjab farmer khalistan referendum',
#  'khalistan sfj modi un punjab farmer khalistan referendum stand sikh community solid',
#  'protest modi khalistan khalistan sfj modi un punjab farmer khalistan referendum',
#  'khalistan sfj modi un punjab farmer khalistan referendum protest u see live utube come',
#  'poorfarmers not alone khalistan sfj modi un punjab farmer khalistan referendum',
#  'khalistan sfj modi un punjab farmer khalistan referendum sikh protest modi gov',
#  'khalistanis high spirit khalistan sfj modi un punjab farmer khalistan referendum',
#  'khalistanis high spirit khalistan sfj modi un punjab farmer khalistan referendum',
#  'protest modi khalistan khalistan sfj modi un punjab farmer khalistan referendum',
#  'stand punjab farmer khalistan sfj modi un punjab farmer khalistan referendum',
#  'khalistan solution protestors raise voice khalistan sfj modi un punjab farmer',
#  'alert live coverage protest raise voice poor farmer khalistan sfj modi un punjab farmer',
#  'punjab haryana people protestiing modi khalistan punjabfarmers watch liv',
#  'b account withhold india response legal demand learn',
#  'b account withhold india response legal demand learn',
#  'b account withhold india response legal demand learn',
#  'b account withhold india response legal demand learn',
#  'stand punjab farmer khalistan sfj modi un punjab farmer khalistan referendum',
#  'protest modi khalistan khalistan sfj modi un punjab farmer khalistan referendum',
#  'live coverage protestors khalistan sfj modi un punjab farmer khalistan referendum',
#  'raise voice punjab farmer khalistan sfj modi un punjab farmer khalistan referendum',
#  'b account withhold india response legal demand learn',
#  'protest modi khalistan khalistan sfj modi un punjab farmer khalistan referendum',
#  'fail leader try blame someone elect modi india fail take stone age stop',
#  'b account withhold india response legal demand learn',
#  'b account withhold india response legal demand learn',
#  'khalistan sfj modi un punjab farmer khalistan referendum sfj call campaign stand',
#  'hashtags khalistan sfj modi un punjab farmer khalistan referendum stand get',
#  'hashtags khalistan sfj modi un punjab farmer khalistan referendum protest modi gov',
#  'hashtags khalistan sfj modi un punjab farmer khalistan referendum stand get',
#  'khalistan sfj modi un punjab farmer khalistan referendum sf jcalls sep protest modi',
#  'khalistan protest modi stand punjab farmer sfj khalistan referendum',
#  'khalistan protest modi stand punjab farmer sfj khalistan referendum',
#  'khalistan protest modi stand punjab farmer sfj khalistan referendum',
#  'b account withhold india response legal demand learn',
#  'b account withhold india response legal demand learn',
#  'b account withhold india response legal demand learn',
#  'b account withhold india response legal demand learn',
#  'b account withhold india response legal demand learn',
#  'khalistan protest modi stand punjab farmer sfj khalistan referendum',
#  'sikh indian army full interview fascinate conversation singh retd regard india c',
#  'hashtags khalistan sfj modi un punjab farmer khalistan referendum come join u protest',
#  'khalistan sfj modi un punjab farmer khalistan referendum protest modi gov gov indi',
#  'khalistan sfj modi un punjab farmer khalistan referendum khalistan street newyork figh',
#  'khalistan sfj modi un punjab farmer khalistan referendum sf jcalls protest modi gov',
#  'khalistan sfj modi un punjab farmer khalistan referendum gov india not cooperate fa',
#  'khalistan protest modi watch live punjab farmer sfj',
#  'protestors road khalistan sfj modi un punjab farmer khalistan referendum',
#  'raise voice farmer punjab farmer khalistan sfj modi un punjab farmer khalistan referendum',
#  'b people haryana punjab special punjab farmer protest modi modi un policy',
#  'stand punjab farmer protest modi khalistan sfj modi un punjab farmer khalistan referendum',
#  'stop modi grab land punjab farmer join sfj protest support sikh farmer modi ex',
#  'b account withhold india response legal demand learn',
#  'b account withhold india response legal demand learn',
#  'b account withhold india response legal demand learn',
#  'b account withhold india response legal demand learn',
#  'b account withhold india response legal demand learn',
#  'spirit protestors high khalistan sfj modi un punjab farmer khalistan referendum catch live cove',
#  'khalistan referendum campaign front un ny watch live guy support khalistan referendum khalistan',
#  'protest modi khalistan sfj modi un punjab farmer khalistan referendum catch live',
#  'stop modi grab land punjab farmer join hand stop truck life farmer',
#  'b account withhold india response legal demand learn',
#  'b account withhold india response legal demand learn',
#  'b account withhold india response legal demand learn',
#  'b account withhold india response legal demand learn',
#  'b account withhold india response legal demand learn',
#  'khalistan protest modi believe ballot no bullet khalistan solution agon',
#  'khalistan protest modi success not final failure not fatal courage continue tha',
#  'khalistan protest modi watch live punjab farmer sfj',
#  'khalistan protest modi step become part campaign stand punjab farmer look',
#  'khalistan protest modi referendum need time put jail observe religiou',
#  'khalistan protest modi watch live farmer tho',
#  'modi un sikh protest no worry how punjab farmer effect call agricultur',
#  'no one happy modi government india punjab farmer protest right anti farmer bil',
#  'khalistan protest modi watch live indian govt try make sikh sla',
#  'khalistan protest modi watch live right farmer sfj',
#  'minority protest delhi newyork modi un khalistan activist protest modi out',
#  'khalistan protest modi watch live punjab farmer sfj khal',
#  'punjab farmer protest right modi un khalistan referendum khalistan',
#  'sfj protest modi un account not get right poor punjab farmer',
#  'spirit people punjab protest watch live',
#  'sjf protest modi un khalistan sfj modi un punjab farmer khalistan referendum',
#  'khalistan protestors thee road modi un khalistan sfj modi un punjab farmer',
#  'khalistan protest modi watch live punjab farmer sfj',
#  'protest modi khalistan khalistan sfj modi un punjab farmer khalistan referendum catch live',
#  'protest modi khalistan khalistan sfj modi un punjab farmer khalistan referendum catch live',
#  'protest khalistan modi khalistan protest modi stand punjab farmer sfj',
#  'stand punjab farmer khalistan protest modi stand punjab farmer sfj',
#  'khalistan protest modi watch live punjab farmer sfj',
#  'raise voice khalistan khalistan protest modi stand punjab farmer sfj',
#  'raise voice modi khalistan protest modi watch live',
#  'modi hitler sikh minority india khalistan referendum modi un sfj khalistan',
#  'sikh protest modi un no worry how punjab farmer effect agriculture bi',
#  'khalistan activist protest modi outside modi un khalistan referendum sfj watch live h',
#  'sfj protest modi un no land grab modi khalistan sikh poor haryana punjab farmer sfj',
#  'khalistan protest modi watch live punjab farmer sfj khalistan referendum',
#  'b account withhold india response legal demand learn',
#  'say yes khalistan hashtags khalistan sfj modi un punjab farmer khalistan referendum',
#  'successful protest modi khalistan solution',
#  'protest modi khalistan khalistan sfj modi un punjab farmer khalistan referendum',
#  'b account withhold india response legal demand learn',
#  'b account withhold india response legal demand learn',
#  'stand punjab farmer khalistan sfj modi un punjab farmer khalistan referendum',
#  'raise voice farmer khalistan sfj modi un punjab farmer khalistan referendum watch live',
#  'b account withhold india response legal demand learn',
#  'b account withhold india response legal demand learn',
#  'b account withhold india response legal demand learn',
#  'b account withhold india response legal demand learn',
#  'b account withhold india response legal demand learn',
#  'justice poorfarmers hashtags khalistan sfj modi un punjab farmer khalistan referendum',
#  'stand punjab farmer khalistan sfj modi un punjab farmer khalistan referendum',
#  'protest modi khalistan sfj modi un punjab farmer khalistan referendum live coverage',
#  'modi un no worry how punjab farmer effect call agriculture reform bill pass federal',
#  'sfj call sikh protest modi un policy punjab farmer',
#  'protest modi khalistan watch live punjab farmer',
#  'khalistan protest modi watch live farmer',
#  'sikh protest modi behaviour policy againat punjab farmer khalistan',
#  'khalistan protest modi watch live indian govt try make si',
#  'khalistan protest modi watch live right farmer',
#  'khalistan protest modi watch live punjab farmer',
#  'b account withhold india response legal demand learn',
#  'pannun pakistani puppet who work pakistan see indian sikh answer referendum shame',
#  'stop modi grab land punjab farmer solution khalistan register vote sfj modi un',
#  'khalistan sfj modi un punjab farmer khalistan referendum come join hand bill pass',
#  'khalistan sfj modi un punjab farmer khalistan referendum stand',
#  'khalistan sfj modi un punjab farmer khalistan referendum stand farmer righ',
#  'khalistan sfj modi un punjab farmer khalistan referendum protest modi sfj come',
#  'khalistan sfj modi un punjab farmer khalistan referendum stand punjab farmer sfj',
#  'khalistan referendum campaign front un ny watch live guy support khalistan referendum',
#  'sikh protest modi act punjab farmer minority india gherao modi',
#  'khalistan activist protest modi outside watch live stand wi',
#  'sfj protest modi un modi stop grab land punjab farmer fight opressi',
#  'raise slogan revolution address',
#  'punjab haryana epicentre nationwide protest farmer sfj khalistan gherao modi',
#  'sfj khalistan gherao modi bharat bandh stop modi grab land punjab farmer',
#  'sfj khalistan gherao modi bharat bandh sfj khalistan gherao modi bharat bandh sfj give call',
#  'say yes khalistan punjab farmer sfj khalistan referendum khalistan protest khalistan sfj modi un',
#  'punjab farmer need help need justice protest khalistan modi khalistan referendum sjf',
#  'raise voice farmer sfj khalistan referendum khalistan sfj modi un punjab farmer',
#  'sfj khalistan gherao modi bharat bandh india government become much corrupt want make sikh',
#  'modi stop grab land poor punjab farmer khalistan register vote',
#  'sfj khalistan gherao modi bharat bandh trucker flock amp block delhi sept',
#  'sfj khalistan gherao modi bharat bandh india government creul want make sikh slave sikh n',
#  'sfj khalistan gherao modi bharat bandh punjab farmer solution khalistan register vote',
#  'sfj khalistan gherao modi bharat bandh india government think sikh slave big mistake',
#  'sfj khalistan gherao modi bharat bandh dehli hilao khalistan banao sfj call gherao modi sept th',
#  'sfj khalistan gherao modi bharat bandh stop modi grab land punjab farmer',
#  'sfj khalistan gherao modi bharat bandh sfj give call gherao modi sept',
#  'sfj khalistan gherao modi bharat bandh indian govt become cruel stand farmer',
#  'sfj khalistan gherao modi bharat bandh dehli hilao khalistan banao sfj call gherao modi sept th',
#  'sfj khalistan gherao modi bharat bandh stop modi grab land punjab farmer',
#  'sfj khalistan gherao modi bharat bandh sfj give call gherao modi sept',
#  'sfj khalistan gherao modi bharat bandh india government become much corrupte instead help farmer',
#  'stop modi grab land punjab farmer solution khalistan register vote sfj modi un',
#  'suicide rate farmer increase alarm every year sfj khalistan gherao modi bharat bandh',
#  'not let modi grab land punjabfarmers sfj khalistan gherao modi bharat bandh',
#  ...]

# %%
#Save preprocessed

# %%
print(type(p1))
# Out:
# <class 'list'>

# %%
f1 = pd.DataFrame(columns = ['tweet','hashtags','label'])
f2 = pd.DataFrame(columns = ['tweet','hashtags','label'])

# %%
f1['tweet'] = pd.Series(p1)
f1.hashtags = d1.tweet_low.apply(lambda x: re.findall(r"#(\w+)", x))
f1.label = 0

# %%
f1.head()
# Out:
#                                                tweet  \
# 0                                day go gettingthere
# 1  friend tell shes afraid go dc rally amp attack...
# 2  ive notice lot icontf presentation mention hap...
# 3          get weekend show country music lylepierce
# 4  final legislative session day officially begin...
#
#                        hashtags  label
# 0                [gettingthere]      0
# 1                  [berniebros]      0
# 2                    [icontf16]      0
# 3  [country, music, lylepierce]      0
# 4                      [albany]      0

# %%
print(type(p2),type(p3))

p2.extend(p3)


h1 = d2.tweet.apply(lambda x: re.findall(r"#(\w+)", x))
h2 = d3.tweet.apply(lambda x: re.findall(r"#(\w+)", x))
htemp = h1.append(h2,ignore_index = True)

f2.tweet = pd.Series(p2)
f2.hashtags = pd.Series(htemp)
f2.label = 1
# Out:
# <class 'list'> <class 'list'>

# %%
print(len(p2))
# Out:
# 5289

# %%
f2
# Out:
#                                                   tweet  \
# 0     pil file twitter promote khalistan good initia...
# 1
# 2     pakistan around partition weve never see photo...
# 3                                 pannun no shame leave
# 4     pannun pakistani puppet who work pakistan see ...
# ...                                                 ...
# 5284                                    referendum vote
# 5285              part democracy take minute referendum
# 5286  true face khalistan not sikh puppet isi shame ...
# 5287  sikh r suffer pakistan amp isi busy support kh...
# 5288  sikh r suffer pakistan amp isi busy support kh...
#
#                                                hashtags  label
# 0              [PIL, Twitter, Khalistan, SikhCommunity]      1
# 1     [Kashmir_With_India, ShameOnSFJ, ShameOnPannun...      1
# 2                                  [Pakistan, Gurdwara]      1
# 3                                   [Pannun, Khalistan]      1
# 4                                               [Shame]      1
# ...                                                 ...    ...
# 5284                                   [Referendum2020]      1
# 5285                                   [Referendum2020]      1
# 5286  [Khalistan, Sikhs, ISI, ShameOnSFJ, ShameOnPan...      1
# 5287                         [Pakistan, ISI, Khalistan]      1
# 5288                         [Pakistan, ISI, Khalistan]      1
#
# [5289 rows x 3 columns]

# %%
f2.to_csv('../Anti-National-Tweets-Classification/dataset/pre_processed/postive_class.csv')
f1.to_csv('../Anti-National-Tweets-Classification/dataset/pre_processed/negative_class.csv')

# %%
df2 = pd.read_csv('../Anti-National-Tweets-Classification/dataset/pre_processed/postive_class.csv')

# %%
# df2 = pd.DataFrame(columns = ['tweet','hashtags','label'])
df2['tweet'] = pd.Series(preprocess_tweets)
df2.hashtags = data.tweet.apply(lambda x: re.findall(r"#(\w+)", x))
df2.label = 1

# %%
df2.head()
# Out:
#                                                tweet  \
# 0  pil file twitter promote khalistan good initia...
# 1  khalistan voice sikh never forget indian state...
# 2  sikh justice mislead sikh community name khali...
# 3  sikh community world include india protest hin...
# 4  pil file twitter promote khalistan good initia...
#
#                                    hashtags  label
# 0  [PIL, Twitter, Khalistan, SikhCommunity]      1
# 1                               [Khalistan]      1
# 2                               [Khalistan]      1
# 3                                   [Refer]      1
# 4  [PIL, Twitter, Khalistan, SikhCommunity]      1

# %%
df2.to_csv('../Anti-National-Tweets-Classification/dataset/pre_processed/postive_class.csv')
