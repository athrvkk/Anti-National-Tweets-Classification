# %%
import tweepy
import csv
import pandas as pd

# %%
class Twitter_Data_Downloader:
    
    def __init__(self):
        consumer_key = '1aWY7LUDcpfRinxw31OFOcbzI'
        consumer_secret = 'NJ0DllMlhoSrWazB2BtAVO21K5rhKKnZzAGL00WmZ1M1YSNHq8'
        access_token = '2904265662-Zv1kX1y1k1Nky8dpMmKJJzrAQLYdQVdDLNwgiYs'
        access_token_secret = '7dofFG4oUInt6L7vPClauLz7jJMVZvxbuo9ta9Ec4HJuC'
        auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
        auth.set_access_token(access_token, access_token_secret)
        self.api = tweepy.API(auth, wait_on_rate_limit=True)        
        
        
    def get_data(self, hashtag, since):
        row = {}
        data = pd.DataFrame(columns= ['user_id','created_at','tweet','hashtags',
                                    'retweet_count','favourite_count', 'tweet_url'])

        for tweet in tweepy.Cursor(self.api.search, q=hashtag, lang="en", since=since).items(10):
            print ("\n", tweet.created_at, tweet.text.encode('utf8'))
            row.update({'user_id' : tweet.author.screen_name.encode('utf8')})
            row.update({'created_at' : tweet.created_at})    
            row.update({'tweet' : tweet.text.encode('utf8')})
            row.update({'hashtags' : tweet.entities.get('hashtags')})
            row.update({'retweet_count' : tweet.retweet_count})
            row.update({'favourite_count' : tweet.favorite_count})
            row.update({'tweet_url' : tweet.entities.get('url')})
            row.update({'tweet_url' : tweet.entities['urls']})
            
            data = data.append(row, ignore_index= True)
        
        name = hashtag.split("#")[1]
        name = "dataset/raw_dataset/"+name+".csv"
        data.to_csv(name)
            
            
    def read_data(self, name):
        name = "dataset/raw_dataset/"+name+".csv"
        df = pd.read_csv(name)
        return df

# %%
tdd = Twitter_Data_Downloader()

# %%
tdd.get_data("#khalistan", "2020-01-01")
# Out:
#  2020-09-29 07:33:52 b"RT @Jas_preet1984: Sikhs For Justice has been misleading the Sikh Community in the name of #Khalistan with the support of Pakistan. It's an\xe2\x80\xa6"
#
#  2020-09-29 07:19:54 b'RT @Suleman2552: The Sikh community all over in the world including India are protesting against Hindutva and RSS terrorism.\nAnd the #Refer\xe2\x80\xa6'
#
#  2020-09-29 07:08:52 b'This #PIL filed against #Twitter for promoting #Khalistan is a good initiative. #SikhCommunity is just trying to sa\xe2\x80\xa6 https://t.co/w8OrEmslpu'
#
#  2020-09-29 06:53:52 b"RT @Jasleen_Kaur11: \xf0\x9f\xa4\xa3\xf0\x9f\x98\x82Now Coming this is a next plan Pakistan  puppet pannun team's. #Kashmir_With_India #ShameOnSFJ #ShameOnPannun #Khalis\xe2\x80\xa6"
#
#  2020-09-29 06:51:23 b"RT @DarrenVirk: #Pakistan around partition as we've never seen it before. Photographs coloured by Ehsan Rehan\nFirst photograph is #Gurdwara\xe2\x80\xa6"
#
#  2020-09-29 06:48:21 b'RT @Harbaks21769227: #Pannun has no shame left. \xf0\x9f\x98\x92 Well, nobody is afraid of you by now whether you print #Khalistan pamphlets or write rubb\xe2\x80\xa6'
#
#  2020-09-29 06:39:49 b"RT @Jasleen_Kaur11: Pannun, a Pakistani puppet who works for Pakistan, see this, Indian Sikh's answer to the Referendum2020  for you.#Shame\xe2\x80\xa6"
#
#  2020-09-29 06:38:54 b'RT @Preetka57645405: There is no #Khalistan, there is only #Khai (Garbage). Dear Sikhs, the quicker you realise Pannun\xe2\x80\x99s tricks, it will be\xe2\x80\xa6'
#
#  2020-09-29 06:33:42 b"RT @kaurmahi829: #Pannun is not listening to #RealSikhs. He is in his own (imaginary) world and doesn't care about the #SikhCommunity. He i\xe2\x80\xa6"
#
#  2020-09-29 05:59:49 b'@TanvirSandhu16 @prakasht291 @rana134788 @surxrjzs @nc_noor @kkr_kp @reachmnc @86_nids @KRSAHIL @pahadan_ @yash19l\xe2\x80\xa6 https://t.co/FLJLDcOC5g'

# %%
data = tdd.read_data('khalistan')
data
# Out:
#    Unnamed: 0             user_id           created_at  \
# 0           0  b'Gurpree91384693'  2020-09-29 07:33:52
# 1           1    b'Jamshaid_2012'  2020-09-29 07:19:54
# 2           2   b'ChopraDilpreet'  2020-09-29 07:08:52
# 3           3         b'jmez1010'  2020-09-29 06:53:52
# 4           4         b'jmez1010'  2020-09-29 06:51:23
# 5           5         b'jmez1010'  2020-09-29 06:48:21
# 6           6         b'jmez1010'  2020-09-29 06:39:49
# 7           7         b'jmez1010'  2020-09-29 06:38:54
# 8           8         b'jmez1010'  2020-09-29 06:33:42
# 9           9       b'saysSubodh'  2020-09-29 05:59:49
#
#                                                tweet  \
# 0  b"RT @Jas_preet1984: Sikhs For Justice has bee...
# 1  b'RT @Suleman2552: The Sikh community all over...
# 2  b'This #PIL filed against #Twitter for promoti...
# 3  b"RT @Jasleen_Kaur11: \xf0\x9f\xa4\xa3\xf0\x9f...
# 4  b"RT @DarrenVirk: #Pakistan around partition a...
# 5  b'RT @Harbaks21769227: #Pannun has no shame le...
# 6  b"RT @Jasleen_Kaur11: Pannun, a Pakistani pupp...
# 7  b'RT @Preetka57645405: There is no #Khalistan,...
# 8  b"RT @kaurmahi829: #Pannun is not listening to...
# 9  b'@TanvirSandhu16 @prakasht291 @rana134788 @su...
#
#                                             hashtags  retweet_count  \
# 0      [{'text': 'Khalistan', 'indices': [91, 101]}]              6
# 1                                                 []             52
# 2  [{'text': 'PIL', 'indices': [5, 9]}, {'text': ...              0
# 3  [{'text': 'Kashmir_With_India', 'indices': [85...              5
# 4  [{'text': 'Pakistan', 'indices': [16, 25]}, {'...             10
# 5  [{'text': 'Pannun', 'indices': [21, 28]}, {'te...             13
# 6                                                 []             29
# 7  [{'text': 'Khalistan', 'indices': [33, 43]}, {...             19
# 8  [{'text': 'Pannun', 'indices': [17, 24]}, {'te...             33
# 9                                                 []              0
#
#    favourite_count                                          tweet_url
# 0                0                                                 []
# 1                0                                                 []
# 2                0  [{'url': 'https://t.co/w8OrEmslpu', 'expanded_...
# 3                0                                                 []
# 4                0                                                 []
# 5                0                                                 []
# 6                0                                                 []
# 7                0                                                 []
# 8                0                                                 []
# 9                0  [{'url': 'https://t.co/FLJLDcOC5g', 'expanded_...
